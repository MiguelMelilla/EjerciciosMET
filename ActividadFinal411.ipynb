# %% [markdown]
# # Actividad Final 4.12

# %% [markdown]
# Calcula la cantidad de agua que hay que añadir para pasar aire atmosférico de 2 °C y al 60 % de humedad a
# 26 °C y al 40 % de humedad.

# %%
from psychrochart import PsychroChart
import os
from psychrolib import *
import matplotlib.pyplot as plt
#Datos de la actividad.
Ts1=2
Hr1=0.60
Ts2=26
Hr2=0.40
P= 101325

W1= GetHumRatioFromRelHum(Ts1,Hr1,P)
W2= GetHumRatioFromRelHum(Ts2,Hr2,P)

Vapor = W2 -W1
print(f"W1: {round(W1*1000,2)} g/Kg\n")
print(f"W2: {round(W2*1000,2)} g/Kg\n")
print(f"Cantidad de vapor: {round(Vapor*1000,2)} g/Kg\n")
# Out:
# W1: 2.61 g/Kg
#
# W2: 8.37 g/Kg
#
# Cantidad de vapor: 5.76 g/Kg

# %% [markdown]
# ![Actividad_Final_4_11.png](attachment:Actividad_Final_4_11.png)
